# %%
path ="texttype.txt"
mv=[]
with open(path,encoding="utf-8") as f:
    lines = f.readlines()
    
    #print(lines[20])
    for l in lines:
        if "[multiverse]" in l:
            mv.append(l.split()[0])
print(mv)
# Out:
# ['1oom', 'aac-enc', 'abs-guide', 'abyss', 'afio', 'album', 'album-data', 'alien-arena', 'alien-arena-data', 'alien-arena-server', 'alsa-firmware-loaders', 'amiwm', 'amoeba', 'amoeba-data', 'anbox', 'arb', 'arb-common', 'arb-doc', 'aseba-plugin-blockly', 'assaultcube', 'assaultcube-data', 'astromenace', 'astromenace-data-src', 'astrometry-data-2mass', 'astrometry-data-2mass-00', 'astrometry-data-2mass-01', 'astrometry-data-2mass-02', 'astrometry-data-2mass-03', 'astrometry-data-2mass-04', 'astrometry-data-2mass-05', 'astrometry-data-2mass-06', 'astrometry-data-2mass-07', 'astrometry-data-2mass-08-19', 'atari800', 'atmel-firmware', 'autodir', 'bart-cuda', 'basilisk2', 'beast-mcmc', 'beast-mcmc-examples', 'bgoffice-dict-downloader', 'blimps-examples', 'blimps-utils', 'bluez-firmware', 'boinc-virtualbox', 'broadcom-sta-common', 'broadcom-sta-dkms', 'broadcom-sta-source', 'brother-cups-wrapper-ac', 'brother-cups-wrapper-bh7', 'brother-cups-wrapper-common', 'brother-cups-wrapper-extra', 'b
# ...
